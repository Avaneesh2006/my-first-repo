# %% [markdown]
# Hardware refers to the physical componets of a computer that you can see and touch, while software refers to the programs and instructions that tell the hardware what to do.
# Example: keyboard is hardware and operating system like Windows is Software.
